# %%
netlist = {
    0: [
        {
            "component": {
                "type": "inductor",
                "location": (773, 345),
                "orientation": "v",
                "nodes": [3, 0]
            },
        },
        {
            "component": {
                "type": "resistor",
                "location": (428, 380),
                "orientation": "v",
                "nodes": [1, 0]
            },
        },
        {
            "component": {
                "type": "source",
                "location": (85, 408),
                "orientation": "v",
                "nodes": [2, 0]
            },
        },
    ],
    1: [
        {
            "component": {
                "type": "resistor",
                "location": (428, 380),
                "orientation": "v",
                "nodes": [1, 0]
            },
        },
        {
            "component": {
                "type": "resistor",
                "location": (277, 281),
                "orientation": "h",
                "nodes": [1, 2]
            },
        },
        {
            "component": {
                "type": "resistor",
                "location": (579, 146),
                "orientation": "h",
                "nodes": [3, 1]
            },
        },
    ],
    2: [
        {
            "component": {
                "type": "source",
                "location": (85, 408),
                "orientation": "v",
                "nodes": [2, 0]
            },
        },
        {
            "component": {
                "type": "resistor",
                "location": (277, 281),
                "orientation": "h",
                "nodes": [1, 2]
            },
        },
    ],
    3: [
        {
            "component": {
                "type": "inductor",
                "location": (773, 345),
                "orientation": "v",
                "nodes": [3, 0]
            },
        },
        {
            "component": {
                "type": "resistor",
                "location": (579, 146),
                "orientation": "h",
                "nodes": [3, 1]
            },
        },
    ]
}

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ --------------
# absl-py                  2.1.0
# arrow                    1.3.0
# asttokens                2.4.1
# astunparse               1.6.3
# cairocffi                1.7.1
# CairoSVG                 2.7.1
# certifi                  2024.2.2
# cffi                     1.17.1
# charset-normalizer       3.3.2
# click                    8.1.7
# colorama                 0.4.6
# comm                     0.2.2
# contourpy                1.2.0
# cssselect2               0.7.0
# cycler                   0.12.1
# debugpy                  1.8.1
# decorator                5.1.1
# defusedxml               0.7.1
# distlib                  0.3.8
# dm-tree                  0.1.8
# docstring_parser         0.16
# etils                    1.9.2
# executing                2.0.1
# filelock                 3.15.4
# flatbuffers              24.3.25
# fonttools                4.49.0
# fsspec                   2024.6.1
# gast                     0.5.4
# google-pasta             0.2.0
# googleapis-common-protos 1.63.2
# greenlet                 3.1.1
# grpcio                   1.64.0
# h5py                     3.11.0
# idna                     3.7
# imageio                  2.34.1
# immutabledict            4.2.0
# importlib_resources      6.4.3
# imutils                  0.5.4
# inform                   1.31
# ipykernel                6.29.4
# ipython                  8.24.0
# jedi                     0.19.1
# joblib                   1.4.2
# jupyter_client           8.6.1
# jupyter_core             5.7.2
# keras                    3.3.3
# kiwisolver               1.4.5
# lazy_loader              0.4
# libclang                 18.1.1
# llvmlite                 0.42.0
# Markdown                 3.6
# markdown-it-py           3.0.0
# MarkupSafe               2.1.5
# matplotlib               3.8.3
# matplotlib-inline        0.1.7
# mdurl                    0.1.2
# ml-dtypes                0.3.2
# namex                    0.0.8
# nest-asyncio             1.6.0
# networkx                 3.3
# numba                    0.59.1
# numpy                    1.26.4
# opencv-python            4.9.0.80
# opt-einsum               3.3.0
# optree                   0.11.0
# packaging                23.2
# pandas                   2.2.1
# parso                    0.8.4
# pillow                   10.2.0
# pip                      24.2
# platformdirs             4.2.1
# promise                  2.3
# prompt-toolkit           3.0.43
# protobuf                 4.25.3
# psutil                   5.9.8
# pure-eval                0.2.2
# pyarrow                  17.0.0
# pycparser                2.22
# Pygments                 2.18.0
# pylsd-nova               1.2.1
# pyparsing                3.1.1
# pytesseract              0.3.10
# python-dateutil          2.8.2
# pytz                     2024.1
# pywin32                  306
# pyzmq                    26.0.3
# requests                 2.32.1
# rich                     13.7.1
# scikit-image             0.23.2
# scikit-learn             1.4.2
# scipy                    1.13.0
# seaborn                  0.13.2
# setuptools               69.5.1
# simple_parsing           0.1.5
# six                      1.16.0
# stack-data               0.6.3
# svg-schematic            1.2.0
# svgwrite                 1.4.3
# tensorboard              2.16.2
# tensorboard-data-server  0.7.2
# tensorflow               2.16.1
# tensorflow-datasets      4.9.6
# tensorflow-intel         2.16.1
# tensorflow-metadata      1.15.0
# termcolor                2.4.0
# threadpoolctl            3.5.0
# tifffile                 2024.5.10
# tinycss2                 1.3.0
# toml                     0.10.2
# tornado                  6.4
# tqdm                     4.66.5
# traitlets                5.14.3
# types-python-dateutil    2.9.0.20241003
# typing_extensions        4.11.0
# tzdata                   2024.1
# urllib3                  2.2.1
# virtualenv               20.26.3
# wcwidth                  0.2.13
# webencodings             0.5.1
# Werkzeug                 3.0.3
# wheel                    0.43.0
# wrapt                    1.16.0
# zipp                     3.20.0

# %%
from svg_schematic import Diode

symbol = Diode(C=(271, 213), orient="h")


symbol.p = (3,4)
print(symbol.p )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from svg_schematic import Diode
# ----> 3 symbol = Diode(C=(271, 213), orient="h")
#       6 symbol.p = (3,4)
#       7 print(symbol.p )
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\svg_schematic.py:762, in Diode.__init__(self, orient, name, value, nudge, color, **kwargs)
#     757 def __init__(self,
#     758     orient='h', name=None, value=None, nudge=5, color='black', **kwargs
#     759 ):
#     760     # Initialization and parameters {{{2
#     761     self.set_coordinates(kwargs, dict(a=(0, -1/2), c=(0, 1/2)), orient, 'h')
# --> 762     super().__init__()
#     763     symbol = self.symbol
#     764     schematic = self.sch_schematic
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\svg_schematic.py:332, in Tile.__init__(self)
#     330 def __init__(self):
#     331     schematic = self.sch_schematic
# --> 332     assert schematic, 'no active schematic'
#     333     lw = schematic.sch_line_width
#     334     w, h = size = self.size
#
# AssertionError: no active schematic

# %%
def generate_cad(netlist):
    from svg_schematic import Schematic, Resistor, Capacitor,\
     Inductor, Source, Diode, Wire
    from inform import Error, error, os_error
    import cairosvg

    with Schematic(filename='circuit_test.svg'):
        for node in netlist:
            components = netlist[node]

            nodes = []
            for component in components:

                symbol = component["type"]
                location = component["coordinate"]
                orientation = component["orientation"]

                # Reistor
                if symbol == "resistor":
                    symbol = Resistor(C=location, orient=orientation)

                # Inductor
                elif symbol == "inductor":
                    symbol = Inductor(C=location, orient=orientation)

                # Capacitor
                elif symbol == "capacitor":
                    symbol = Capacitor(C=location, orient=orientation)

                # Power Supply
                elif symbol == "source":
                    symbol = Source(C=location, orient=orientation, kind="vdc")

                # Diode
                elif symbol == "diode":
                    symbol = Diode(C=location, orient=orientation)
                    symbol.p = symbol.a
                    symbol.n = symbol.c

                # Component not recognized
                else:
                    continue

                # getting negative or positive end of component
                if node == component["nodes"][1]:
                    nodes.append(symbol.p)
                elif node == component["nodes"][0]:
                    nodes.append(symbol.n)
                else:
                    continue

                Wire(nodes, "-|")

    cairosvg.svg2png(url="/content/circuit_test.svg",
                     write_to="/content/generated_schematic.png")

# %%
import json

with open('netlist.json', 'w') as fp:
    json.dump(netlist, fp)

# %%
with open('netlist.json', 'r') as file:
    netlistJson = json.load(file)

# %%
generate_cad(netlist)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 generate_cad(netlist)
#
# Cell In[4], line 5, in generate_cad(netlist)
#       2 from svg_schematic import Schematic, Resistor, Capacitor,\
#       3  Inductor, Source, Diode, Wire
#       4 from inform import Error, error, os_error
# ----> 5 import cairosvg
#       7 with Schematic(filename='circuit_test.svg'):
#       8     for node in netlist:
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\cairosvg\__init__.py:26
#      22 VERSION = __version__ = (ROOT / 'VERSION').read_text().strip()
#      25 # VERSION is used in the "url" module imported by "surface"
# ---> 26 from . import surface  # noqa isort:skip
#      29 SURFACES = {
#      30     'PDF': surface.PDFSurface,
#      31     'PNG': surface.PNGSurface,
#    (...)
#      34     'SVG': surface.SVGSurface,
#      35 }
#      38 def svg2svg(bytestring=None, *, file_obj=None, url=None, dpi=96,
#      39             parent_width=None, parent_height=None, scale=1, unsafe=False,
#      40             background_color=None, negate_colors=False, invert_images=False,
#      41             write_to=None, output_width=None, output_height=None):
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\cairosvg\surface.py:9
#       6 import copy
#       7 import io
# ----> 9 import cairocffi as cairo
#      11 from .colors import color, negate_color
#      12 from .defs import (
#      13     apply_filter_after_painting, apply_filter_before_painting, clip_path,
#      14     filter_, gradient_or_pattern, linear_gradient, marker, mask, paint_mask,
#      15     parse_all_defs, pattern, prepare_filter, radial_gradient, use)
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\cairocffi\__init__.py:60
#      55     error_message = '\n'.join(  # pragma: no cover
#      56         str(exception) for exception in exceptions)
#      57     raise OSError(error_message)  # pragma: no cover
# ---> 60 cairo = dlopen(
#      61     ffi, ('cairo-2', 'cairo', 'libcairo-2'),
#      62     ('libcairo.so.2', 'libcairo.2.dylib', 'libcairo-2.dll'))
#      65 class _keepref(object):  # noqa: N801
#      66     """Function wrapper that keeps a reference to another object."""
#
# File c:\Users\Nicollas Fernandes\AppData\Local\Programs\Python\Python312\Lib\site-packages\cairocffi\__init__.py:57, in dlopen(ffi, library_names, filenames)
#      53         exceptions.append(exception)
#      55 error_message = '\n'.join(  # pragma: no cover
#      56     str(exception) for exception in exceptions)
# ---> 57 raise OSError(error_message)
#
# OSError: no library called "cairo-2" was found
# no library called "cairo" was found
# no library called "libcairo-2" was found
# cannot load library 'libcairo.so.2': error 0x7e.  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo.so.2'
# cannot load library 'libcairo.2.dylib': error 0x7e.  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo.2.dylib'
# cannot load library 'libcairo-2.dll': error 0x7e.  Additionally, ctypes.util.find_library() did not manage to locate a library called 'libcairo-2.dll'
